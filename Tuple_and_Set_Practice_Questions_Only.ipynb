# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
a = 1,2,3,4,5
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
a = (1,3.1,"aman",True)
print(a[0])
print(a[1])
print(a[2])
print(a[3])
# Out:
# 1
# 3.1
# aman
# True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
a = ("Aman", "Priya", "Sakshi", "Ritu")
print(len(a))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
a = 1,2,3,4,5
print(a[-1])
# Out:
# 5

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
a = 1,2,3,4,5
find = 5
if find in a:
  print("True")
else:
  print("False")
# Out:
# True

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
a = 1,2,3,4,5
my_list = list(a)
print(type(my_list))
# Out:
# <class 'list'>

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
a = 1,2,3,4,5
my_tuple = tuple(a)
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
a = 1,2,3,4,5,1,1,1,2,2,3,4
for i in a:

  print(a.count(i))
# Out:
# 4
# 3
# 2
# 2
# 1
# 4
# 4
# 4
# 3
# 3
# 2
# 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
a = ("Aman", "Priya", "Sakshi", "Ritu")
print(a.index("Sakshi"))
# Out:
# 2

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
a = ("Aman", "Priya", "Sakshi", "Ritu")
a.append("Aman")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1988402369.py in <cell line: 0>()
#       1 # write your answer here
#       2 a = ("Aman", "Priya", "Sakshi", "Ritu")
# ----> 3 a.append("Aman")
#
# AttributeError: 'tuple' object has no attribute 'append'
